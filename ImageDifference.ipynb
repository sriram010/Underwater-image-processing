# %%
import cv2

# %% [markdown]
# <h1> Original Image

# %%
image_path = r"E:\mini_project\Underwater-image-processing\Backend\ImageProcessing\TestImages\129_img_.png"
image = cv2.imread(image_path)
print ("Original Iamge: ", image)
# Out:
# Original Iamge:  [[[ 86  81   6]
#   [ 86  81   6]
#   [ 84  79   4]
#   ...
#   [201 131   0]
#   [199 132   0]
#   [197 132   0]]
#
#  [[ 84  79   4]
#   [ 84  79   4]
#   [ 83  78   3]
#   ...
#   [196 129   2]
#   [195 130   1]
#   [193 131   0]]
#
#  [[ 84  79   4]
#   [ 83  78   3]
#   [ 83  78   3]
#   ...
#   [184 125   2]
#   [185 127   2]
#   [185 127   2]]
#
#  ...
#
#  [[ 95 107   7]
#   [ 95 105   5]
#   [ 95 103   3]
#   ...
#   [120 120   2]
#   [122 121   7]
#   [126 122  10]]
#
#  [[ 96 123   3]
#   [ 94 116   0]
#   [ 96 109   0]
#   ...
#   [117 119   0]
#   [115 114   2]
#   [115 113   5]]
#
#  [[ 92 117   3]
#   [ 92 111   0]
#   [ 95 107   1]
#   ...
#   [118 119   0]
#   [115 113   1]
#   [114 111   2]]]

# %% [markdown]
# <h1>Red Channel Compensation

# %%
image_path = r"E:\mini_project\Underwater-image-processing\Backend\ImageProcessing\OutputImages\red_channel_compensated_image.png"
image1 = cv2.imread(image_path)
print ("Red Channel Compensated Image:\n", image1)
# Out:
# Red Channel Compensated Image:
#  [[[ 86  81  16]
#   [ 86  81  20]
#   [ 84  79  24]
#   ...
#   [201 131  30]
#   [199 132  24]
#   [197 132  18]]
#
#  [[ 84  79  20]
#   [ 84  79  25]
#   [ 83  78  31]
#   ...
#   [196 129  40]
#   [195 130  32]
#   [193 131  24]]
#
#  [[ 84  79  24]
#   [ 83  78  31]
#   [ 83  78  38]
#   ...
#   [184 125  50]
#   [185 127  41]
#   [185 127  31]]
#
#  ...
#
#  [[ 95 107  36]
#   [ 95 105  46]
#   [ 95 103  57]
#   ...
#   [120 120  61]
#   [122 121  49]
#   [126 122  38]]
#
#  [[ 96 123  30]
#   [ 94 116  38]
#   [ 96 109  46]
#   ...
#   [117 119  48]
#   [115 114  38]
#   [115 113  29]]
#
#  [[ 92 117  23]
#   [ 92 111  28]
#   [ 95 107  35]
#   ...
#   [118 119  36]
#   [115 113  28]
#   [114 111  21]]]

# %%
comp_img = image - image1
print("Differnce between Original and Red channel compensated image:\n", comp_img)
# Out:
# Differnce between Original and Red channel compensated image:
#  [[[  0   0 246]
#   [  0   0 242]
#   [  0   0 236]
#   ...
#   [  0   0 226]
#   [  0   0 232]
#   [  0   0 238]]
#
#  [[  0   0 240]
#   [  0   0 235]
#   [  0   0 228]
#   ...
#   [  0   0 218]
#   [  0   0 225]
#   [  0   0 232]]
#
#  [[  0   0 236]
#   [  0   0 228]
#   [  0   0 221]
#   ...
#   [  0   0 208]
#   [  0   0 217]
#   [  0   0 227]]
#
#  ...
#
#  [[  0   0 227]
#   [  0   0 215]
#   [  0   0 202]
#   ...
#   [  0   0 197]
#   [  0   0 214]
#   [  0   0 228]]
#
#  [[  0   0 229]
#   [  0   0 218]
#   [  0   0 210]
#   ...
#   [  0   0 208]
#   [  0   0 220]
#   [  0   0 232]]
#
#  [[  0   0 236]
#   [  0   0 228]
#   [  0   0 222]
#   ...
#   [  0   0 220]
#   [  0   0 229]
#   [  0   0 237]]]

# %% [markdown]
# <h1> White Balancing

# %%
image_path = r"E:\mini_project\Underwater-image-processing\Backend\ImageProcessing\OutputImages\white_balanced_image.png"
image2 = cv2.imread(image_path)
print("White Balanced Image:\n", image2)
# Out:
# White Balanced Image:
#  [[[ 86  87  35]
#   [ 86  87  43]
#   [ 84  85  52]
#   ...
#   [201 142  65]
#   [199 143  52]
#   [197 143  39]]
#
#  [[ 84  85  43]
#   [ 84  85  54]
#   [ 83  84  68]
#   ...
#   [196 139  87]
#   [195 141  70]
#   [193 142  52]]
#
#  [[ 84  85  52]
#   [ 83  84  68]
#   [ 83  84  83]
#   ...
#   [184 135 109]
#   [185 137  90]
#   [185 137  68]]
#
#  ...
#
#  [[ 95 116  79]
#   [ 95 113 101]
#   [ 95 111 125]
#   ...
#   [120 130 134]
#   [122 131 107]
#   [126 132  83]]
#
#  [[ 96 133  65]
#   [ 94 125  83]
#   [ 96 118 101]
#   ...
#   [117 129 105]
#   [115 123  83]
#   [115 122  63]]
#
#  [[ 92 126  50]
#   [ 92 120  61]
#   [ 95 116  76]
#   ...
#   [118 129  79]
#   [115 122  61]
#   [114 120  46]]]

# %%
wb_img = image2 - image1
print("Difference between White balanced image and Red channel compensated image:\n", wb_img)
# Out:
# Difference between White balanced image and Red channel compensated image:
#  [[[ 0  6 19]
#   [ 0  6 23]
#   [ 0  6 28]
#   ...
#   [ 0 11 35]
#   [ 0 11 28]
#   [ 0 11 21]]
#
#  [[ 0  6 23]
#   [ 0  6 29]
#   [ 0  6 37]
#   ...
#   [ 0 10 47]
#   [ 0 11 38]
#   [ 0 11 28]]
#
#  [[ 0  6 28]
#   [ 0  6 37]
#   [ 0  6 45]
#   ...
#   [ 0 10 59]
#   [ 0 10 49]
#   [ 0 10 37]]
#
#  ...
#
#  [[ 0  9 43]
#   [ 0  8 55]
#   [ 0  8 68]
#   ...
#   [ 0 10 73]
#   [ 0 10 58]
#   [ 0 10 45]]
#
#  [[ 0 10 35]
#   [ 0  9 45]
#   [ 0  9 55]
#   ...
#   [ 0 10 57]
#   [ 0  9 45]
#   [ 0  9 34]]
#
#  [[ 0  9 27]
#   [ 0  9 33]
#   [ 0  9 41]
#   ...
#   [ 0 10 43]
#   [ 0  9 33]
#   [ 0  9 25]]]

# %% [markdown]
# <h1> Retinex with Dense Pixels

# %%
image_path = r"E:\mini_project\Underwater-image-processing\Backend\ImageProcessing\OutputImages\retinex_image.png"
image3 = cv2.imread(image_path)
print("Retinex Image:\n", image3)
# Out:
# Retinex Image:
#  [[[ 94  96  38]
#   [ 93  95  46]
#   [ 85  87  53]
#   ...
#   [204 144  66]
#   [202 147  53]
#   [200 146  39]]
#
#  [[ 85  87  44]
#   [ 86  88  55]
#   [ 84  86  69]
#   ...
#   [200 141  89]
#   [197 142  71]
#   [195 143  53]]
#
#  [[ 86  88  53]
#   [ 84  86  69]
#   [ 84  86  84]
#   ...
#   [186 135 110]
#   [195 145  95]
#   [195 146  72]]
#
#  ...
#
#  [[ 96 118  80]
#   [ 98 117 104]
#   [ 96 112 127]
#   ...
#   [122 133 137]
#   [124 133 108]
#   [128 135  85]]
#
#  [[ 99 136  66]
#   [ 95 127  84]
#   [ 98 121 103]
#   ...
#   [119 131 107]
#   [121 129  87]
#   [116 124  64]]
#
#  [[ 94 128  50]
#   [ 96 125  63]
#   [ 96 118  77]
#   ...
#   [121 133  81]
#   [118 124  62]
#   [118 123  47]]]

# %%
ret_img = image3 - image2
print("Difference between Retinex image and White balanced image:\n", ret_img)
# Out:
# Difference between Retinex image and White balanced image:
#  [[[ 8  9  3]
#   [ 7  8  3]
#   [ 1  2  1]
#   ...
#   [ 3  2  1]
#   [ 3  4  1]
#   [ 3  3  0]]
#
#  [[ 1  2  1]
#   [ 2  3  1]
#   [ 1  2  1]
#   ...
#   [ 4  2  2]
#   [ 2  1  1]
#   [ 2  1  1]]
#
#  [[ 2  3  1]
#   [ 1  2  1]
#   [ 1  2  1]
#   ...
#   [ 2  0  1]
#   [10  8  5]
#   [10  9  4]]
#
#  ...
#
#  [[ 1  2  1]
#   [ 3  4  3]
#   [ 1  1  2]
#   ...
#   [ 2  3  3]
#   [ 2  2  1]
#   [ 2  3  2]]
#
#  [[ 3  3  1]
#   [ 1  2  1]
#   [ 2  3  2]
#   ...
#   [ 2  2  2]
#   [ 6  6  4]
#   [ 1  2  1]]
#
#  [[ 2  2  0]
#   [ 4  5  2]
#   [ 1  2  1]
#   ...
#   [ 3  4  2]
#   [ 3  2  1]
#   [ 4  3  1]]]

# %% [markdown]
# <h1>Adaptive Histogram Tranformation

# %%
image_path = r"E:\mini_project\Underwater-image-processing\Backend\ImageProcessing\OutputImages\adaptive_histogram_image.png"
image4 = cv2.imread(image_path)
print("Adaptive Histrogram Transer Image:\n", image4)
# Out:
# Adaptive Histrogram Transer Image:
#  [[[ 86  77  30]
#   [ 86  82  41]
#   [ 81  83  49]
#   ...
#   [209 142  58]
#   [210 140  58]
#   [212 140  58]]
#
#  [[ 86  80  45]
#   [ 87  86  56]
#   [ 83  86  63]
#   ...
#   [196 149  75]
#   [202 147  60]
#   [206 145  48]]
#
#  [[ 82  79  57]
#   [ 86  85  70]
#   [ 86  91  81]
#   ...
#   [183 144 107]
#   [193 147  85]
#   [192 141  63]]
#
#  ...
#
#  [[ 97 130  85]
#   [101 131  95]
#   [104 128 102]
#   ...
#   [124 144 128]
#   [127 146 108]
#   [118 135  87]]
#
#  [[100 132  82]
#   [103 132  87]
#   [104 130  89]
#   ...
#   [114 132 100]
#   [114 130  85]
#   [107 119  69]]
#
#  [[ 96 122  74]
#   [ 98 123  75]
#   [ 98 122  75]
#   ...
#   [111 126  84]
#   [108 119  71]
#   [103 111  59]]]

# %%
fin_img = image4 - image3
print("Difference between histogram transfered immage and Retinex image:\n", fin_img)
# Out:
# Difference between histogram transfered immage and Retinex image:
#  [[[248 237 248]
#   [249 243 251]
#   [252 252 252]
#   ...
#   [  5 254 248]
#   [  8 249   5]
#   [ 12 250  19]]
#
#  [[  1 249   1]
#   [  1 254   1]
#   [255   0 250]
#   ...
#   [252   8 242]
#   [  5   5 245]
#   [ 11   2 251]]
#
#  [[252 247   4]
#   [  2 255   1]
#   [  2   5 253]
#   ...
#   [253   9 253]
#   [254   2 246]
#   [253 251 247]]
#
#  ...
#
#  [[  1  12   5]
#   [  3  14 247]
#   [  8  16 231]
#   ...
#   [  2  11 247]
#   [  3  13   0]
#   [246   0   2]]
#
#  [[  1 252  16]
#   [  8   5   3]
#   [  6   9 242]
#   ...
#   [251   1 249]
#   [249   1 254]
#   [247 251   5]]
#
#  [[  2 250  24]
#   [  2 254  12]
#   [  2   4 254]
#   ...
#   [246 249   3]
#   [246 251   9]
#   [241 244  12]]]
